# %% [markdown]
# ![image.png](attachment:286360e0-6c9c-4759-ad58-07b5b3e7ee51.png)

# %%
a = input("Enter sentence")

words = a.split()
unique_words = set(words)

print("Unique words count:", len(unique_words))
print("Unique words:", unique_words)
# Out:
# Enter sentence python is easy and python is powerful
# Unique words count: 5
# Unique words: {'is', 'easy', 'python', 'powerful', 'and'}

# %% [markdown]
# ![image.png](attachment:9e3d9dc6-e124-4aa6-a948-81fcf85ff0e3.png)

# %%
employees = {"Ravi": 75000,"Anita": 68000,"Kiran": 72000}

employee = max(employees, key=employees.get)

print("Highest Salary:", max_employee, "-", employees[max_employee])

# %% [markdown]
# ![image.png](attachment:de4ec65b-e8e1-494f-94a7-f3fccaeb3ba3.png)

# %%
numbers = [45, 22, 89, 10, 66]

max_val = numbers[0]
min_val = numbers[0]

for num in numbers:
    if num > max_val:
        max_val = num
    if num < min_val:
        min_val = num

print("List:", numbers)
print("Max:", max_val)
print("Min:", min_val)
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %% [markdown]
# ![image.png](attachment:227c6d52-3f8d-4467-8843-8780624e9cce.png)

# %%
prices = [450, 1200, 899, 1500, 300]

c = 0

for i in prices:
    if i > 1000:
        c += 1

print("Products above 1000:", c)
# Out:
# Products above 1000: 2

# %% [markdown]
# ![image.png](attachment:7445b343-e315-477b-b453-90291c990648.png)

# %%
attendance = ["P", "P", "A", "P", "P"]

present = attendance.count("P")
total = len(attendance)

percentage = (present / total) * 100

print("Attendance Percentage:", percentage)
# Out:
# Attendance Percentage: 80.0

# %% [markdown]
# ![image.png](attachment:65ef8ae3-887f-4dc0-987b-36205d78dd6f.png)

# %%
phone_numbers = [9876543210, 9123456789, 9876543210]

unique_numbers = set(phone_numbers)

print("Unique phone numbers:", unique_numbers)
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %% [markdown]
# ![image.png](attachment:6d7730d9-3d22-4187-b2d9-1a6ec11240b5.png)

# %%
text = "python"

freq = {}

for char in text:
    if char in freq:
        freq[char] += 1
    else:
        freq[char] = 1

print(freq)
# Out:
# {'p': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %% [markdown]
# ![image.png](attachment:0dd27452-aec4-438a-a6fd-e1a177f5b40f.png)

# %%
lst = [10, 20, 30]

tup = tuple(lst)

print("Tuple:", tup)
# Out:
# Tuple: (10, 20, 30)

# %% [markdown]
# ![image.png](attachment:c1c81624-25d0-46a5-b31c-e0a6f5716eda.png)

# %%
employees = {"Ravi": 75000,"Anita": 68000}

key = "Ravi"

if key in employees:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Employee exists

# %% [markdown]
# ![image.png](attachment:964a7d56-8478-43d9-8f63-29c95185912d.png)

# %%
marks = [70, 75, 80, 65]

average = sum(marks) / len(marks)

print("Average Marks:", average)
# Out:
# Average Marks: 72.5
